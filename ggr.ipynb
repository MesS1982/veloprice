# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import seaborn as sns
ggr = pd.read_csv('data\Регистрация на соревнования.csv')

# %%
ggr.iloc[0] = 30
ggr = ggr.drop(index=11)
ggr
# Out:
#                  Отметка времени         Имя    Фамилия  \
# 0                             30          30         30
# 1   2023/02/08 12:21:47 AM GMT+4        Вова    Голубев
# 2   2023/02/08 12:27:56 AM GMT+4      Никита    Соколов
# 3   2023/02/08 12:40:18 AM GMT+4     Akeksei  Krivoguz
# 4   2023/02/08 12:48:31 AM GMT+4   Златесса    Тенилова
# 5   2023/02/08 12:50:07 AM GMT+4      Sergey  Baranchuk
# 6   2023/02/08 12:52:16 AM GMT+4      $erega   Dedushev
# 7    2023/02/12 9:27:45 PM GMT+4  Konstantin      Kraev
# 8   2023/02/17 11:50:27 PM GMT+4     Андрей     Петров
# 9   2023/02/17 11:55:15 PM GMT+4       Мужик    В Трико
# 10  2023/02/17 11:55:39 PM GMT+4       Denis  Afonenkov
# 12  2023/02/18 12:11:53 PM GMT+4     Виталий     Иванов
#
#        Ник в telegram-чате Возраст                      Категория  \
# 0                       30      30                             30
# 1                 @vorodya      35  Шоссе - грэвел - фикс мужчины
# ...

# %%
ggr
# Out:
#                  Отметка времени         Имя    Фамилия  \
# 0                             30          30         30
# 1   2023/02/08 12:21:47 AM GMT+4        Вова    Голубев
# 2   2023/02/08 12:27:56 AM GMT+4      Никита    Соколов
# 3   2023/02/08 12:40:18 AM GMT+4     Akeksei  Krivoguz
# 4   2023/02/08 12:48:31 AM GMT+4   Златесса    Тенилова
# 5   2023/02/08 12:50:07 AM GMT+4      Sergey  Baranchuk
# 6   2023/02/08 12:52:16 AM GMT+4      $erega   Dedushev
# 7    2023/02/12 9:27:45 PM GMT+4  Konstantin      Kraev
# 8   2023/02/17 11:50:27 PM GMT+4     Андрей     Петров
# 9   2023/02/17 11:55:15 PM GMT+4       Мужик    В Трико
# 10  2023/02/17 11:55:39 PM GMT+4       Denis  Afonenkov
# 12  2023/02/18 12:11:53 PM GMT+4     Виталий     Иванов
#
#        Ник в telegram-чате Возраст                      Категория  \
# 0                       30      30                             30
# 1                 @vorodya      35  Шоссе - грэвел - фикс мужчины
# ...

# %%
sns.histplot(
    data=ggr,
    x='Возраст',
    bins=10,
    
)
sns.set_context(rc={'axes.labelsize': 9.0,
'axes.linewidth': 1.0,
'axes.titlesize': 10.0})
plt.xlabel('Возраст')
plt.ylabel('Количество участников')
plt.title('Гистрограмма распределения возраста участников', fontsize=15);
